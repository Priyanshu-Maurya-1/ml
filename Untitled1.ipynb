# %%
import pandas as pd
import numpy as np
df= pd.read_csv('education_expenditure_supplementary_data.csv',engine='python')
df
# Out:
#                   country                  institute_type  \
# 0            OECD Average               All Institutions
# 1               Australia               All Institutions
# 2                 Austria               All Institutions
# 3                 Belgium               All Institutions
# 4                  Canada               All Institutions
# ..                    ...                             ...
# 328                Turkey  Higher Education Institutions
# 329        United Kingdom  Higher Education Institutions
# 330         United States  Higher Education Institutions
# 331                Brazil  Higher Education Institutions
# 332    Russian Federation  Higher Education Institutions
#
#     direct_expenditure_type  1995  2000  2005  2009  2010  2011
# 0                    Public   4.9   4.9   5.0   5.4   5.4   5.3
# 1                    Public   4.5   4.6   4.3   4.5   4.6   4.3
# 2                    Public   5.3   5.4   5.2   5.7   5.6   5.5
# ...

# %%
dfx=df.dropna(thresh=5)
dfx
# Out:
#                   country                  institute_type  \
# 0            OECD Average               All Institutions
# 1               Australia               All Institutions
# 2                 Austria               All Institutions
# 3                 Belgium               All Institutions
# 4                  Canada               All Institutions
# ..                    ...                             ...
# 106                Turkey  Higher Education Institutions
# 107        United Kingdom  Higher Education Institutions
# 108         United States  Higher Education Institutions
# 109                Brazil  Higher Education Institutions
# 110    Russian Federation  Higher Education Institutions
#
#     direct_expenditure_type  1995  2000  2005  2009  2010  2011
# 0                    Public   4.9   4.9   5.0   5.4   5.4   5.3
# 1                    Public   4.5   4.6   4.3   4.5   4.6   4.3
# 2                    Public   5.3   5.4   5.2   5.7   5.6   5.5
# ...

# %%
df_mean=dfx.fillna(df1.mean())
df_mean
# Out:
# C:\Users\princ\AppData\Local\Temp/ipykernel_19388/2494132673.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_mean=dfx.fillna(df1.mean())
#                   country                  institute_type  \
# 0            OECD Average               All Institutions
# 1               Australia               All Institutions
# 2                 Austria               All Institutions
# 3                 Belgium               All Institutions
# 4                  Canada               All Institutions
# ..                    ...                             ...
# 106                Turkey  Higher Education Institutions
# 107        United Kingdom  Higher Education Institutions
# 108         United States  Higher Education Institutions
# 109                Brazil  Higher Education Institutions
# ...

# %%
import matplotlib.pyplot as plt

# %%
df_mean
# Out:
#                   country                  institute_type  \
# 0            OECD Average               All Institutions
# 1               Australia               All Institutions
# 2                 Austria               All Institutions
# 3                 Belgium               All Institutions
# 4                  Canada               All Institutions
# ..                    ...                             ...
# 106                Turkey  Higher Education Institutions
# 107        United Kingdom  Higher Education Institutions
# 108         United States  Higher Education Institutions
# 109                Brazil  Higher Education Institutions
# 110    Russian Federation  Higher Education Institutions
#
#     direct_expenditure_type      1995      2000      2005     2009      2010  \
# 0                    Public  4.900000  4.900000  5.000000  5.40000  5.400000
# 1                    Public  4.500000  4.600000  4.300000  4.50000  4.600000
# ...

# %%
plt.scatter(df_mean['2005'],df_mean['2011'])

# %%
from sklearn import preprocessing

std_scale = preprocessing.StandardScaler().fit(df_mean[['2000','2011']])
df_std = std_scale.transform(df_mean[['2000','2011']])

minmax_scale = preprocessing.MinMaxScaler().fit(df_mean[['2000','2011']])
df_minmax = minmax_scale.transform(df_mean[['2000','2011']])

# %%
df_std['2011']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19388/350122316.py in <module>
# ----> 1 df_std['2011']
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
